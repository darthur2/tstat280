# %% [markdown]
# ### Bike Store Sales Analysis

# %% [markdown]
# You are a data analyst for a bike store and you have been tasked with performing some queries on the sales database to answer some important questions.

# %% [markdown]
# #### Part 1
#
# Complete the code block to perform a query that does the following:
#
# - For products released after 2015, find the average list price for each category.
# - Only include categories where the average price is greater than $800.
# - Display the category_id and average price, sorted from highest to lowest average price.

# %%
import sqlite3

conn = sqlite3.connect("bike_store.db")
cursor = conn.cursor()

cursor.execute("""
    SELECT NULL /* Replace with your own query */
""").fetchall()
# Out:
# [(None,)]

# %% [markdown]
# #### Part 2
#
# Complete the code block to perform a query that does the following:
#
# - Join the order_items and products tables to display the product name, quantity, and discount for each ordered item.
# - Only include items where the discount is greater than 0.10.
# - Shows only the first 10 results

# %%
cursor.execute("""
    SELECT NULL /* Replace with your own query */
""").fetchall()
# Out:
# [("Electra Townie Original 7D EQ - Women's - 2016", 1, 0.2),
#  ('Trek Fuel EX 8 29 - 2016', 1, 0.2),
#  ('Electra Townie Original 7D EQ - 2016', 2, 0.2),
#  ("Electra Girl's Hawaii 1 (20-inch) - 2015/2016", 2, 0.2),
#  ('Trek Remedy 29 Carbon Frameset - 2016', 1, 0.2),
#  ("Electra Townie Original 7D EQ - Women's - 2016", 2, 0.2),
#  ('Ritchey Timberwolf Frameset - 2016', 2, 0.2),
#  ('Trek Conduit+ - 2016', 2, 0.2),
#  ('Electra Moto 1 - 2016', 2, 0.2),
#  ('Electra Cruiser 1 (24-Inch) - 2016', 1, 0.2)]
