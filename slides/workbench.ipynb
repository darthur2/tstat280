# %% [markdown]
# # Python & Data Science Environment Setup Guide
#
# We will be learning up to set up your data science workbench. Setting up your workbench includes:
#
# - Downloading and installing the Python interpreter
# - Familiarizing yourself with the terminal
# - Learning about Git and how to use Git via GitHub Desktop
# - Learning about virtual environments, why they are important, and how to create one
# - Familiarizing yourself with and installing several common Python libraries used by data scientists
# - Learning about Jupyter Notebooks and JupyterLab and how to run JupyterLab on your own computer

# %% [markdown]
# # What is a Python Interpreter?
#
# A Python interpreter is a program that reads and executes Python code. When you write Python code, the interpreter runs it line by line. You can download the interpreter here:
#
# https://www.python.org/downloads/
#
# <div>
# <img src="attachment:05cd20e4-539f-4b07-853c-923b2198b559.png" width="700" alt="Python download page showing different download options"/>
# </div>
#
#
# - Download Python 3.x
# - On Windows: Check "Add Python to PATH"
# - On Mac: Use the official installer package

# %% [markdown]
# # What is a Terminal?
#
# A terminal is a text-based interface that allows you to interact with your computer using commands.
#
# - Windows -> PowerShell
# - Mac -> Terminal
#
# <div>
# <img src="attachment:bd65e947-5463-4c64-8db6-1cea621234b9.png" width="500" alt="Windows PowerShell terminal"/>
# </div>
#
# You use the terminal to:
#
# - Navigate folders
# - Create directories
# - Install packages
# - Run Python, Jupyter Notebooks, or JupyterLab (more on that later)

# %% [markdown]
# # How to Open the Terminal
#
# Before running commands, you need to open a terminal window.
#
# ## On Windows (PowerShell)
#
# 1. Click the **Start Menu**
# 2. Type **PowerShell**
# 3. Click **Windows PowerShell**
#
# ## On Mac (Terminal)
#
# 1. Press **Command (⌘) + Space**
# 2. Type **Terminal**
# 3. Press Enter

# %% [markdown]
# # Checking Python Installation
#
# To make sure Python installed correctly, open your terminal and run **one** of the following commands:
#
# ```bash
# python --version
# ```
#
# If that doesn’t work, try:
#
# ```bash
# python3 --version
# ```
#
# On some Windows systems, you may need:
#
# ```bash
# py --version
# ```
#
# <div>
# <img src="attachment:02dcdbe5-3458-42d7-955a-21c5b860b6bf.png" width="500" alt="Using Windows PowerShell terminal to check Python version using version command"/>
# </div>

# %% [markdown]
# # Basic Terminal Commands
#
# Here are the most important commands you’ll use:
#
# | Command | What It Does |
# |----------|--------------|
# | `ls` | Lists files in the current directory |
# | `cd folder_name` | Changes into a directory named `folder_name` |
# | `cd ..` | Moves up one directory |
# | `mkdir folder_name` | Creates a new directory named `folder_name` |
# | `pwd` | Prints the current working directory |
#
# ---
#
# ## Example
#
# <div>
# <img src="attachment:9ff09808-c2a1-4c77-a790-e906714ca0ae.png" width="500" alt="Illustrating cd and ls command in Windows PowerShell to change directories and list files"/>
# </div>

# %% [markdown]
# # What is Git
#
# Git is a version control system. It allows you to:
#
# - Track changes in code
# - Save snapshots of your work
# - Revert to earlier versions
# - Collaborate with others

# %% [markdown]
# # Creating a GitHub Account
#
# GitHub is a website that stores Git repositories online.
#
# In this course, we will use GitHub to:
# - Store your projects in the cloud
# - Submit assignments
# - Track changes to your work
# - Share code
#
# ---
#
# ## Step 1: Go to GitHub
#
# Visit:
#
# https://github.com/
#
# Click **Sign up** in the top-right corner.
#
# <div>
# <img src="attachment:a880e1fd-7a9f-4cfa-8722-1d79473924d1.png" width="500" alt="Sign-in page for GitHub with sign-up button highlighted"/>
# </div>
#
# ---
#
# ## Step 2: Create Your Account
#
# You will be asked to provide:
#
# - An email address
# - A password
# - A username
#
# Choose a professional username (you may use GitHub in future internships or jobs).
#
# ---
#
# ## Step 3: Verify Your Email
#
# After signing up, GitHub will send you a verification email.
# Open it and confirm your account.
#
# ---
#
# ## Step 4: Log In
#
# Once your account is verified, log in at:
#
# https://github.com/login
#
# ---
#
# ## ✅ You’re Done!
#
# You now have a GitHub account.
#
# Next, we will connect GitHub to GitHub Desktop so you can easily clone repositories, commit changes, and push your work.

# %% [markdown]
# # Forking the Course Repository
#
# To submit your own work, you need your *own copy* of the course repository.
#
# We do this using something called a **fork**.
#
# <div>
# <img src="attachment:0681cb79-8a6c-4d0a-afb5-972dc775d431.png" width="500" alt="Repository page with fork button highlighted"/>
# </div>
#
# ## What is a Fork?
#
# A **fork** creates a copy of a repository under *your own GitHub account*.
#
# After you fork:
#
# - You can make changes freely
# - You can push updates
# - You control your version
# - The original course repository remains unchanged
#
# ---
#
# ## Why We Use Forking in This Course
#
# If you clone the instructor's repository directly, you **cannot push changes** to it.
#
# By forking:
#
# - You create your own version
# - You push to your version
# - You submit the link to your repository

# %% [markdown]
# # Using Git via GitHub Desktop
#
# We will use GitHub Desktop for simplicity. Download it here:
#
# https://desktop.github.com/
#
# <div>
# <img src="attachment:2b639ef7-e741-463d-9911-6f05b8781552.png" width="500" alt="GitHub Desktop page with download button highlighted"/>
# </div>

# %% [markdown]
# # Cloning a Git Repository
#
# Cloning means downloading a repository from GitHub to your computer. After copying and pasting the the link to the repository, do the following in GitHub Desktop:
#
# - File -> Clone Repository
# - Select URL
# - Input URL for repository
# - Choose local folder where repository will be stored
# - Click clone
#
# You can now navigate to this repository in the terminal on your machine.
#
# <div>
# <img src="attachment:21bcd6ed-c0e0-45ab-b0c8-e0f56d8ba4ea.png" width="500" alt="GitHub repository with code button highlighted"/>
# </div>
#
# <div>
# <img src="attachment:156331aa-7c39-4d78-9d76-613c4a952262.png" width="500" alt="GitHub repository with repository URL highlighted"/>
# </div>
#
# <div>
# <img src="attachment:e083ce46-8fbc-42af-a1c7-063251142776.png" width="500" alt="GitHub Desktop with clone option highlighted under File menu"/>
# </div>

# %% [markdown]
# # Virtual Environments
#
# A virtual environment is an isolated Python environment. These are useful because different projects may require:
#
# - Different package versions
# - Different dependencies
#
# Virtual environments prevent conflicts between projects.

# %% [markdown]
# # Creating a Virtual Environment
#
# A virtual environment keeps your project’s Python packages isolated from other projects.
#
# ---
#
# ## Step 1: Navigate to Your Project Folder
#
# Open your terminal and move into your project directory:
#
# ```bash
# cd my_project
# ```
#
# ---
#
# ## Step 2: Create the Virtual Environment
#
# Run:
#
# ```bash
# python -m venv venv
# ```
#
# This creates a new folder named `venv` inside your project.
#
# ---
#
# ## Step 3: Activate the Virtual Environment
#
# ### 🍎 On Mac / Linux
#
# ```bash
# source venv/bin/activate
# ```
#
# ### 🪟 On Windows (PowerShell)
#
# ```powershell
# venv\Scripts\activate
# ```
#
# ---
#
# ## ✅ Confirm It Worked
#
# You should now see `(venv)` at the beginning of your terminal line, for example:
#
# ```text
# (venv) user@computer my_project %
# ```
#
# This means your virtual environment is active.
#
# ---
#
# ## Deactivate the Virtual Environment
#
# When you're finished working, run:
#
# ```bash
# deactivate
# ```

# %% [markdown]
# # 📦 Install Data Science Libraries
#
# Once your virtual environment is activated, install the required libraries by running:
#
# ```bash
# pip install numpy pandas matplotlib seaborn scikit-learn jupyterlab
# ```
#
# This command installs all required packages for the course in one step.
#
# ---
#
# ## 📚 Library Documentation
#
# Below are the official documentation links for each library. These are valuable references throughout the course.
#
# ### NumPy
# Numerical computing and arrays
# https://numpy.org/doc/
#
# ### Pandas
# Data manipulation and DataFrames
# https://pandas.pydata.org/docs/
#
# ### Matplotlib
# Core plotting library
# https://matplotlib.org/stable/contents.html
#
# ### Seaborn
# Statistical data visualization (built on Matplotlib)
# https://seaborn.pydata.org/
#
# ### Scikit-Learn
# Machine learning tools
# https://scikit-learn.org/stable/
#
# ### JupyterLab
# Interactive development environment for notebooks
# https://jupyterlab.readthedocs.io/

# %% [markdown]
# # Running JupyterLab
#
# Now we are ready to run JupyterLab. In the terminal, run:
#
# ```bash
# jupyter lab
# ```
#
# This will start a local server on your machine where JupyterLab is running.

# %% [markdown]
# # JupyterLab Interface Overview
# ## File Browser (Left Panel)
#
# Browse and open files.
#
# ## Launcher
#
# Create notebooks, consoles, or terminals.
#
# ## Notebook Area
#
# Write and execute code.
#
# ## Terminal (Inside JupyterLab)
#
# You can open a terminal inside JupyterLab if needed.

# %% [markdown]
# # What is a Jupyter Notebook
#
# A Jupyter Notebook contains:
#
# - Code cells (Python code)
# - Markdown cells (text explanations)
# - Output (tables, plots, results)
#
# You can mix code and explanation in the same document.
