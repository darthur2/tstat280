# %% [markdown]
# # Slide 1
#
# This is a slide with an equation $y = \beta_0 + \beta_1 x$.

# %% [markdown]
# # Slide 2
#
# This is a slide with another equation $L(y, \hat{y}) = (y - \hat{y})^2$

# %%
x = 2
y = 3

x + y
# Out:
# 5
