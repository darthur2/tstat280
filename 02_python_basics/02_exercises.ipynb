# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Exercise 1
#
# Create a list called `numbers` that contains the values `[2, 4, 6]`.
#
# Then:
# 1. Add the number `8` to the end of the list
# 2. Remove the last element from the list and store it in a variable called `removed`
# 3. Print the updated list
# 4. Print the value of `removed`

# %%
# Put your code here

# %% [markdown]
# #### Exercise 2
#
# Create a dictionary called `student` with the following key-value pairs:
# - `"name"` → `"Alex"`
# - `"age"` → `20`
#
# Then:
# 1. Add a new key `"major"` with the value `"Biology"`
# 2. Update the `"age"` to `21`
# 3. Print the value associated with `"name"`
# 4. Print the entire dictionary

# %%
# Put your code here

# %% [markdown]
# #### Exercise 3
#
# Given the list below:
#
# ```python
# numbers = [10, 20, 30, 40, 50]
# ```
#
# Complete the following:
# 1. Print the element at index 2
# 2. Print the last element of the list
# 3. Print the first three elements using slicing

# %%
# Put your code here

# %% [markdown]
# #### Exercise 4
#
# Given the string below:
#
# ```python
# text = "python"
# ```
#
# Complete the following:
# 1. Print the first character
# 2. Print the last character
# 3. Print the substring "yth" using slicing

# %%
# Put your code here

# %% [markdown]
# #### Exercise 5
#
# Given the NumPy array below:
#
# ```python
# arr = np.array([[1, 2, 3],
#                 [4, 5, 6]])
# ```
#
# Complete the following:
# 1. Print the element in the second row, third column
# 2. Print the entire first row
# 3. Print the first two columns using slicing

# %%
# Put your code here

# %% [markdown]
# #### Exercise 6
#
# Given the list below:
#
#     numbers = [1, 2, 3, 4]
#
# Write a `for` loop that:
# 1. Iterates through each number in the list
# 2. Prints each number divided by 2

# %%
# Put your code here

# %% [markdown]
# #### Exercise 7
#
# Given the list below:
#
#     numbers = [1, 2, 3, 4, 5]
#
# Create a new list called `result` that contains only the numbers less than or equal to 3.
#
# Then print `result`.

# %%
# Put your code here

# %% [markdown]
# #### Exercise 8
#
# Write a program that:
# 1. Sets a variable `number` equal to a value of your choice
# 2. Uses an `if`/`else` statement to check:
#    - If the number is greater than 10, print `"Greater than 10"`
#    - Otherwise, print `"10 or less"`

# %%
# Put your code here

# %% [markdown]
# #### Exercise 9
#
# Write a program that:
# 1. Imports the `math` library
# 2. Defines a function called `square_root_sum` that takes two numbers as parameters
# 3. Inside the function:
#    - Add the two numbers
#    - Return the square root of the sum using a function from the `math` library
# 4. Call the function with two numbers of your choice and print the result

# %%
# Put your code here
